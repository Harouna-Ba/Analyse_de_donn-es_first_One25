# %%
import pandas as pd

# %%
df = pd.read_csv("data.csv")

# %%
df.head()
# Out:
#    id        date first_name   last_name                  email  gender  \
# 0   1  03/28/2021    Marylin      Alders   malders0@shop-pro.jp    Male
# 1   2  03/19/2021      Hinda    Harridge     hharridge1@gnu.org  Female
# 2   3  03/17/2021        Erl  Kilminster  ekilminster2@etsy.com    Male
# 3   4  03/19/2021      Grata      Brantl       gbrantl3@umn.edu  Female
# 4   5  03/24/2021      Kanya     Beasant    kbeasant4@jigsy.com    Male
#
#         ip_address        country price_paid   tax
# 0    160.119.8.119         Canada      $5.36   NaN
# 1   210.51.172.132         Canada      $8.32   NaN
# 2    213.8.101.145  United States      $3.73  20.0
# 3    5.140.237.101  United States      $3.70  20.0
# 4  106.252.162.233        Morocco      $9.24  20.0

# %%
df.tail()
# Out:
#                               id        date first_name last_name  gender  \
# email
# derrigorn@elpais.com         996  03/24/2021       Duff    Errigo  Female
# arastallro@toplist.cz        997  03/17/2021        Ame   Rastall  Female
# bstickelsrp@cloudflare.com   998  03/13/2021      Betty  Stickels    Male
# ptesoerq@rakuten.co.jp       999  03/17/2021    Paquito     Tesoe    Male
# rpringuerrr@house.gov       1000  03/23/2021   Rochelle  Pringuer     NaN
#
#                                 ip_address        country price_paid   tax
# email
# derrigorn@elpais.com        193.84.247.144         France      $3.63   NaN
# arastallro@toplist.cz       188.219.12.109            NaN      $4.59  20.0
# bstickelsrp@cloudflare.com    199.80.60.87  United States      $7.54  20.0
# ptesoerq@rakuten.co.jp         0.183.63.11  United States      $5.81   NaN
# rpringuerrr@house.gov       170.193.249.83         Canada      $8.01  20.0

# %%
#ceci est un test Harouna

# %%
df.shape
# Out:
# (1000, 9)

# %%
df.columns
# Out:
# Index(['id', 'date', 'first_name', 'last_name', 'email', 'gender',
#        'ip_address', 'country', 'price_paid', 'tax'],
#       dtype='object')

# %%
df.columns.tolist()
# Out:
# ['id',
#  'date',
#  'first_name',
#  'last_name',
#  'gender',
#  'ip_address',
#  'country',
#  'price_paid',
#  'tax']

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
#df.set_index("email") #remplacer le in dex par la colonne email

# %%
#df.set_index("email", inplace= True) #afin d'avoir le remplecement pris en compte

# %%
df.shape
# Out:
# (1000, 9)

# %% [raw]
# #Selectionner des données

# %%
df.first_name.tail()
# Out:
# 995        Duff
# 996         Ame
# 997       Betty
# 998     Paquito
# 999    Rochelle
# Name: first_name, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          1000 non-null   int64
#  1   date        1000 non-null   object
#  2   first_name  1000 non-null   object
#  3   last_name   1000 non-null   object
#  4   email       1000 non-null   object
#  5   gender      931 non-null    object
#  6   ip_address  1000 non-null   object
#  7   country     956 non-null    object
#  8   price_paid  1000 non-null   object
#  9   tax         654 non-null    float64
# dtypes: float64(1), int64(1), object(8)
# memory usage: 78.3+ KB

# %%
df.dtypes
# Out:
# id              int64
# date           object
# first_name     object
# last_name      object
# email          object
# gender         object
# ip_address     object
# country        object
# price_paid     object
# tax           float64
# dtype: object

# %%
#si on veut selectionner des elements
df[10:20]
# Out:
#     id        date first_name  last_name                       email  gender  \
# 10  11  03/11/2021       Lief  Woodcraft   lwoodcrafta@sitemeter.com    Male
# 11  12  03/16/2021     Bailie      Wyman            bwymanb@lulu.com    Male
# 12  13  03/05/2021     Janice   Morillas  jmorillasc@miibeian.gov.cn  Female
# 13  14  03/24/2021       Cull     Vassie          cvassied@unblog.fr     NaN
# 14  15  03/21/2021     Oralie     Maryon             omaryone@va.gov  Female
# 15  16  03/24/2021     Julina      Faint        jfaintf@amazon.co.jp  Female
# 16  17  03/27/2021        Eve    Allaway        eallawayg@ebay.co.uk  Female
# 17  18  03/20/2021       Esta    Boulden     ebouldenh@posterous.com     NaN
# 18  19  03/16/2021      Judye      Behan           jbehani@google.es  Female
# 19  20  03/01/2021     Sibeal     Mounch      smounchj@rakuten.co.jp    Male
#
#          ip_address        country price_paid   tax
# 10    201.76.240.51         Canada      $5.71   NaN
# ...

# %%
# si on veut utiliser la fonction loc
df.loc[['lwoodcrafta@sitemeter.com','jfaintf@amazon.co.jp']]
# Out:
#                            id        date first_name  last_name  gender  \
# email
# lwoodcrafta@sitemeter.com  11  03/11/2021       Lief  Woodcraft    Male
# jfaintf@amazon.co.jp       16  03/24/2021     Julina      Faint  Female
#
#                               ip_address        country price_paid   tax
# email
# lwoodcrafta@sitemeter.com  201.76.240.51         Canada      $5.71   NaN
# jfaintf@amazon.co.jp        96.193.4.151  United States      $4.10  20.0

# %% [markdown]
# #les filtres

# %%
#les filtres de cibler differents ranger
df["gender"] =="Male"#cibler les valeurs d'une colonnes
# Out:
# email
# malders0@shop-pro.jp           True
# hharridge1@gnu.org            False
# ekilminster2@etsy.com          True
# gbrantl3@umn.edu              False
# kbeasant4@jigsy.com            True
#                               ...
# derrigorn@elpais.com          False
# arastallro@toplist.cz         False
# bstickelsrp@cloudflare.com     True
# ptesoerq@rakuten.co.jp         True
# rpringuerrr@house.gov         False
# Name: gender, Length: 1000, dtype: bool

# %%
df[df["gender"] =="Male"] #filtre sur les genre Male uniquement
# Out:
#                              id        date first_name   last_name gender  \
# email
# malders0@shop-pro.jp          1  03/28/2021    Marylin      Alders   Male
# ekilminster2@etsy.com         3  03/17/2021        Erl  Kilminster   Male
# kbeasant4@jigsy.com           5  03/24/2021      Kanya     Beasant   Male
# cfeasley7@ed.gov              8  03/08/2021       Codi     Feasley   Male
# wheersema8@tumblr.com         9  03/09/2021     Waylon    Heersema   Male
# ...                         ...         ...        ...         ...    ...
# ecrushrj@berkeley.edu       992  03/07/2021      Elihu       Crush   Male
# mguilloneaurk@about.me      993  03/04/2021    Maurene  Guilloneau   Male
# osnellerl@nhs.uk            994  03/22/2021      Ossie      Snelle   Male
# bstickelsrp@cloudflare.com  998  03/13/2021      Betty    Stickels   Male
# ptesoerq@rakuten.co.jp      999  03/17/2021    Paquito       Tesoe   Male
#
# ...

# %%
Female_filter = df["gender"] =="Female"
df[Female_filter] #filtre sur les genre Male uniquement
# Out:
#                              id        date first_name   last_name  gender  \
# email
# hharridge1@gnu.org            2  03/19/2021      Hinda    Harridge  Female
# gbrantl3@umn.edu              4  03/19/2021      Grata      Brantl  Female
# tbraybrooke5@umn.edu          6  03/25/2021      Titos  Braybrooke  Female
# akencott6@phoca.cz            7  03/14/2021        Ava     Kencott  Female
# jmorillasc@miibeian.gov.cn   13  03/05/2021     Janice    Morillas  Female
# ...                         ...         ...        ...         ...     ...
# ylongworthyrd@163.com       986  03/29/2021     Yvonne  Longworthy  Female
# ybotlerrg@miitbeian.gov.cn  989  03/07/2021       Yves      Botler  Female
# cbruntjenrm@reference.com   995  03/17/2021   Carolyne    Bruntjen  Female
# derrigorn@elpais.com        996  03/24/2021       Duff      Errigo  Female
# arastallro@toplist.cz       997  03/17/2021        Ame     Rastall  Female
#
# ...

# %%
country_filter = df["country"].isin(["France","Canada"])

# %%
df[country_filter]
# Out:
#                              id        date first_name   last_name  gender  \
# email
# malders0@shop-pro.jp          1  03/28/2021    Marylin      Alders    Male
# hharridge1@gnu.org            2  03/19/2021      Hinda    Harridge  Female
# akencott6@phoca.cz            7  03/14/2021        Ava     Kencott  Female
# cfeasley7@ed.gov              8  03/08/2021       Codi     Feasley    Male
# wheersema8@tumblr.com         9  03/09/2021     Waylon    Heersema    Male
# ...                         ...         ...        ...         ...     ...
# mguilloneaurk@about.me      993  03/04/2021    Maurene  Guilloneau    Male
# osnellerl@nhs.uk            994  03/22/2021      Ossie      Snelle    Male
# cbruntjenrm@reference.com   995  03/17/2021   Carolyne    Bruntjen  Female
# derrigorn@elpais.com        996  03/24/2021       Duff      Errigo  Female
# rpringuerrr@house.gov      1000  03/23/2021   Rochelle    Pringuer     NaN
#
# ...

# %%
df[df["price_paid"] > 5]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[101], line 1
# ----> 1 df[df["price_paid"] > 5]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\ops\common.py:81, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      77             return NotImplemented
#      79 other = item_from_zerodim(other)
# ---> 81 return method(self, other)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\arraylike.py:56, in OpsMixin.__gt__(self, other)
#      54 @unpack_zerodim_and_defer("__gt__")
#      55 def __gt__(self, other):
# ---> 56     return self._cmp_method(other, operator.gt)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:6096, in Series._cmp_method(self, other, op)
#    6093 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
#    6095 with np.errstate(all="ignore"):
# ...

# %%
df_test = df.copy()
df_test.price_paid = df_test.price_paid.apply(lambda x: x.replace("$", ""))
df_test.price_paid = df_test.price_paid.astype(float)

# %%
df_test[df_test.price_paid > 5]
# Out:
#        id        date first_name   last_name                       email  \
# 0       1  03/28/2021    Marylin      Alders        malders0@shop-pro.jp
# 1       2  03/19/2021      Hinda    Harridge          hharridge1@gnu.org
# 4       5  03/24/2021      Kanya     Beasant         kbeasant4@jigsy.com
# 5       6  03/25/2021      Titos  Braybrooke        tbraybrooke5@umn.edu
# 6       7  03/14/2021        Ava     Kencott          akencott6@phoca.cz
# ..    ...         ...        ...         ...                         ...
# 992   993  03/04/2021    Maurene  Guilloneau      mguilloneaurk@about.me
# 994   995  03/17/2021   Carolyne    Bruntjen   cbruntjenrm@reference.com
# 997   998  03/13/2021      Betty    Stickels  bstickelsrp@cloudflare.com
# 998   999  03/17/2021    Paquito       Tesoe      ptesoerq@rakuten.co.jp
# 999  1000  03/23/2021   Rochelle    Pringuer       rpringuerrr@house.gov
#
#      gender       ip_address        country  price_paid   tax
# ...

# %% [markdown]
# #supprimer une colonne

# %%
df.drop("ip_address", axis = 1, inplace = True)

# %%
df
# Out:
#        id        date first_name   last_name                       email  \
# 0       1  03/28/2021    Marylin      Alders        malders0@shop-pro.jp
# 1       2  03/19/2021      Hinda    Harridge          hharridge1@gnu.org
# 2       3  03/17/2021        Erl  Kilminster       ekilminster2@etsy.com
# 3       4  03/19/2021      Grata      Brantl            gbrantl3@umn.edu
# 4       5  03/24/2021      Kanya     Beasant         kbeasant4@jigsy.com
# ..    ...         ...        ...         ...                         ...
# 995   996  03/24/2021       Duff      Errigo        derrigorn@elpais.com
# 996   997  03/17/2021        Ame     Rastall       arastallro@toplist.cz
# 997   998  03/13/2021      Betty    Stickels  bstickelsrp@cloudflare.com
# 998   999  03/17/2021    Paquito       Tesoe      ptesoerq@rakuten.co.jp
# 999  1000  03/23/2021   Rochelle    Pringuer       rpringuerrr@house.gov
#
#      gender        country price_paid   tax
# 0      Male         Canada      $5.36   NaN
# ...

# %%
#supprimer plusieurs colonnes
#pour cela, il fau utiliser une liste

# %%
df.drop(["first_name", "last_name"], axis = 1, inplace = True)

# %%
df
# Out:
#        id        date                       email  gender        country  \
# 0       1  03/28/2021        malders0@shop-pro.jp    Male         Canada
# 1       2  03/19/2021          hharridge1@gnu.org  Female         Canada
# 2       3  03/17/2021       ekilminster2@etsy.com    Male  United States
# 3       4  03/19/2021            gbrantl3@umn.edu  Female  United States
# 4       5  03/24/2021         kbeasant4@jigsy.com    Male        Morocco
# ..    ...         ...                         ...     ...            ...
# 995   996  03/24/2021        derrigorn@elpais.com  Female         France
# 996   997  03/17/2021       arastallro@toplist.cz  Female            NaN
# 997   998  03/13/2021  bstickelsrp@cloudflare.com    Male  United States
# 998   999  03/17/2021      ptesoerq@rakuten.co.jp    Male  United States
# 999  1000  03/23/2021       rpringuerrr@house.gov     NaN         Canada
#
#     price_paid   tax
# 0        $5.36   NaN
# 1        $8.32   NaN
# 2        $3.73  20.0
# ...

# %%
df.set_index("gender", inplace = True)

# %%
df
# Out:
#           id        date                       email        country  \
# gender
# Male       1  03/28/2021        malders0@shop-pro.jp         Canada
# Female     2  03/19/2021          hharridge1@gnu.org         Canada
# Male       3  03/17/2021       ekilminster2@etsy.com  United States
# Female     4  03/19/2021            gbrantl3@umn.edu  United States
# Male       5  03/24/2021         kbeasant4@jigsy.com        Morocco
# ...      ...         ...                         ...            ...
# Female   996  03/24/2021        derrigorn@elpais.com         France
# Female   997  03/17/2021       arastallro@toplist.cz            NaN
# Male     998  03/13/2021  bstickelsrp@cloudflare.com  United States
# Male     999  03/17/2021      ptesoerq@rakuten.co.jp  United States
# NaN     1000  03/23/2021       rpringuerrr@house.gov         Canada
#
#        price_paid   tax
# gender
# Male        $5.36   NaN
# Female      $8.32   NaN
# Male        $3.73  20.0
# Female      $3.70  20.0
# ...

# %% [markdown]
# #traiter des valeurs manquantes

# %%
df.isnull()
# Out:
#            id   date  country  price_paid    tax
# gender
# Male    False  False    False       False   True
# Female  False  False    False       False   True
# Male    False  False    False       False  False
# Female  False  False    False       False  False
# Male    False  False    False       False  False
# ...       ...    ...      ...         ...    ...
# Female  False  False    False       False   True
# Female  False  False     True       False  False
# Male    False  False    False       False  False
# Male    False  False    False       False   True
# NaN     False  False    False       False  False
#
# [1000 rows x 5 columns]

# %%
df.notnull()
# Out:
#           id  date  country  price_paid    tax
# gender
# Male    True  True     True        True  False
# Female  True  True     True        True  False
# Male    True  True     True        True   True
# Female  True  True     True        True   True
# Male    True  True     True        True   True
# ...      ...   ...      ...         ...    ...
# Female  True  True     True        True  False
# Female  True  True    False        True   True
# Male    True  True     True        True   True
# Male    True  True     True        True  False
# NaN     True  True     True        True   True
#
# [1000 rows x 5 columns]

# %%
df[df.tax.notnull()]
# Out:
#           id        date        country price_paid   tax
# gender
# Male       3  03/17/2021  United States      $3.73  20.0
# Female     4  03/19/2021  United States      $3.70  20.0
# Male       5  03/24/2021        Morocco      $9.24  20.0
# Male       8  03/08/2021         France      $3.01  20.0
# Male       9  03/09/2021         Canada      $3.70  20.0
# ...      ...         ...            ...        ...   ...
# Male     992  03/07/2021        Morocco      $5.05  20.0
# Female   995  03/17/2021         France      $5.68  20.0
# Female   997  03/17/2021            NaN      $4.59  20.0
# Male     998  03/13/2021  United States      $7.54  20.0
# NaN     1000  03/23/2021         Canada      $8.01  20.0
#
# [654 rows x 5 columns]

# %%
df[df["tax"].isnull()]
# Out:
#          id        date                   email        country price_paid  tax
# gender
# Male      1  03/28/2021    malders0@shop-pro.jp         Canada      $5.36  NaN
# Female    2  03/19/2021      hharridge1@gnu.org         Canada      $8.32  NaN
# Female    6  03/25/2021    tbraybrooke5@umn.edu  United States      $5.82  NaN
# Female    7  03/14/2021      akencott6@phoca.cz         Canada      $6.29  NaN
# Male     10  03/23/2021   ggookes9@amazon.co.uk         France      $9.05  NaN
# ...     ...         ...                     ...            ...        ...  ...
# Female  986  03/29/2021   ylongworthyrd@163.com         France      $9.16  NaN
# Male    993  03/04/2021  mguilloneaurk@about.me         France      $9.19  NaN
# Male    994  03/22/2021        osnellerl@nhs.uk         France      $4.31  NaN
# Female  996  03/24/2021    derrigorn@elpais.com         France      $3.63  NaN
# Male    999  03/17/2021  ptesoerq@rakuten.co.jp  United States      $5.81  NaN
#
# ...

# %%
df.tax.fillna(0)  #remplacer les nan par 0
# Out:
# gender
# Male       0.0
# Female     0.0
# Male      20.0
# Female    20.0
# Male      20.0
#           ...
# Female     0.0
# Female    20.0
# Male      20.0
# Male       0.0
# NaN       20.0
# Name: tax, Length: 1000, dtype: float64

# %%
df.dropna(subset=["tax"], inplace = True)

# %%
df
# Out:
# gender
# Male      3.73
# Female    3.70
# Male      9.24
# Male      3.01
# Male      3.70
#           ...
# Male      5.05
# Female    5.68
# Female    4.59
# Male      7.54
# NaN       8.01
# Name: price_paid, Length: 654, dtype: object

# %%
#faire des clacul afin de trouver la sommes des payements

# %%
df
# Out:
#           id        date                       email        country  \
# gender
# Male       3  03/17/2021       ekilminster2@etsy.com  United States
# Female     4  03/19/2021            gbrantl3@umn.edu  United States
# Male       5  03/24/2021         kbeasant4@jigsy.com        Morocco
# Male       8  03/08/2021            cfeasley7@ed.gov         France
# Male       9  03/09/2021       wheersema8@tumblr.com         Canada
# ...      ...         ...                         ...            ...
# Male     992  03/07/2021       ecrushrj@berkeley.edu        Morocco
# Female   995  03/17/2021   cbruntjenrm@reference.com         France
# Female   997  03/17/2021       arastallro@toplist.cz            NaN
# Male     998  03/13/2021  bstickelsrp@cloudflare.com  United States
# NaN     1000  03/23/2021       rpringuerrr@house.gov         Canada
#
#        price_paid   tax
# gender
# Male        $3.73  20.0
# Female      $3.70  20.0
# Male        $9.24  20.0
# Male        $3.01  20.0
# ...

# %%
df.price_paid = df.price_paid.apply(lambda x: x.replace("$", ""))
df.price_paid =  df.price_paid.astype(float)

# %%
df.dtypes
# Out:
# id              int64
# date           object
# email          object
# country        object
# price_paid    float64
# tax           float64
# dtype: object

# %%
df
# Out:
#           id        date                       email        country  \
# gender
# Male       3  03/17/2021       ekilminster2@etsy.com  United States
# Female     4  03/19/2021            gbrantl3@umn.edu  United States
# Male       5  03/24/2021         kbeasant4@jigsy.com        Morocco
# Male       8  03/08/2021            cfeasley7@ed.gov         France
# Male       9  03/09/2021       wheersema8@tumblr.com         Canada
# ...      ...         ...                         ...            ...
# Male     992  03/07/2021       ecrushrj@berkeley.edu        Morocco
# Female   995  03/17/2021   cbruntjenrm@reference.com         France
# Female   997  03/17/2021       arastallro@toplist.cz            NaN
# Male     998  03/13/2021  bstickelsrp@cloudflare.com  United States
# NaN     1000  03/23/2021       rpringuerrr@house.gov         Canada
#
#         price_paid   tax
# gender
# Male          3.73  20.0
# Female        3.70  20.0
# Male          9.24  20.0
# Male          3.01  20.0
# ...

# %%
#multiplier les valeurs des paiemenst et celles des taxes

# %%
df["total_paid"] = df["price_paid"] * df["tax"]

# %%
df
# Out:
#           id        date                       email        country  \
# gender
# Male       3  03/17/2021       ekilminster2@etsy.com  United States
# Female     4  03/19/2021            gbrantl3@umn.edu  United States
# Male       5  03/24/2021         kbeasant4@jigsy.com        Morocco
# Male       8  03/08/2021            cfeasley7@ed.gov         France
# Male       9  03/09/2021       wheersema8@tumblr.com         Canada
# ...      ...         ...                         ...            ...
# Male     992  03/07/2021       ecrushrj@berkeley.edu        Morocco
# Female   995  03/17/2021   cbruntjenrm@reference.com         France
# Female   997  03/17/2021       arastallro@toplist.cz            NaN
# Male     998  03/13/2021  bstickelsrp@cloudflare.com  United States
# NaN     1000  03/23/2021       rpringuerrr@house.gov         Canada
#
#         price_paid   tax  total_paid
# gender
# Male          3.73  20.0        74.6
# Female        3.70  20.0        74.0
# ...

# %%
del df["total_paid"]

# %%
df
# Out:
#           id        date                       email        country  \
# gender
# Male       3  03/17/2021       ekilminster2@etsy.com  United States
# Female     4  03/19/2021            gbrantl3@umn.edu  United States
# Male       5  03/24/2021         kbeasant4@jigsy.com        Morocco
# Male       8  03/08/2021            cfeasley7@ed.gov         France
# Male       9  03/09/2021       wheersema8@tumblr.com         Canada
# ...      ...         ...                         ...            ...
# Male     992  03/07/2021       ecrushrj@berkeley.edu        Morocco
# Female   995  03/17/2021   cbruntjenrm@reference.com         France
# Female   997  03/17/2021       arastallro@toplist.cz            NaN
# Male     998  03/13/2021  bstickelsrp@cloudflare.com  United States
# NaN     1000  03/23/2021       rpringuerrr@house.gov         Canada
#
#         price_paid   tax
# gender
# Male          3.73  20.0
# Female        3.70  20.0
# Male          9.24  20.0
# Male          3.01  20.0
# ...

# %%
df["price_total"] = df["price_paid"]*(1 - df["tax"]/100)

# %%
df
# Out:
#           id        date                       email        country  \
# gender
# Male       3  03/17/2021       ekilminster2@etsy.com  United States
# Female     4  03/19/2021            gbrantl3@umn.edu  United States
# Male       5  03/24/2021         kbeasant4@jigsy.com        Morocco
# Male       8  03/08/2021            cfeasley7@ed.gov         France
# Male       9  03/09/2021       wheersema8@tumblr.com         Canada
# ...      ...         ...                         ...            ...
# Male     992  03/07/2021       ecrushrj@berkeley.edu        Morocco
# Female   995  03/17/2021   cbruntjenrm@reference.com         France
# Female   997  03/17/2021       arastallro@toplist.cz            NaN
# Male     998  03/13/2021  bstickelsrp@cloudflare.com  United States
# NaN     1000  03/23/2021       rpringuerrr@house.gov         Canada
#
#         price_paid   tax  price_total
# gender
# Male          3.73  20.0        2.984
# Female        3.70  20.0        2.960
# ...

# %%
Countries = {"United States" : "UN", "France" : "FR", "Canada" : "CA", "Morocco" : "MA"}
df.country = df.country.map(Countries)

# %%
df
# Out:
#           id        date                       email country  price_paid  \
# gender
# Male       3  03/17/2021       ekilminster2@etsy.com      UN        3.73
# Female     4  03/19/2021            gbrantl3@umn.edu      UN        3.70
# Male       5  03/24/2021         kbeasant4@jigsy.com      MA        9.24
# Male       8  03/08/2021            cfeasley7@ed.gov      FR        3.01
# Male       9  03/09/2021       wheersema8@tumblr.com      CA        3.70
# ...      ...         ...                         ...     ...         ...
# Male     992  03/07/2021       ecrushrj@berkeley.edu      MA        5.05
# Female   995  03/17/2021   cbruntjenrm@reference.com      FR        5.68
# Female   997  03/17/2021       arastallro@toplist.cz     NaN        4.59
# Male     998  03/13/2021  bstickelsrp@cloudflare.com      UN        7.54
# NaN     1000  03/23/2021       rpringuerrr@house.gov      CA        8.01
#
#          tax  price_total
# gender
# Male    20.0        2.984
# ...

# %%
#Analyser les données de notre Datframe

# %%
df.describe()
# Out:
#                 id  price_paid    tax  price_total
# count   654.000000  654.000000  654.0   654.000000
# mean    500.860856    6.371789   20.0     5.097431
# std     288.765128    2.053502    0.0     1.642802
# min       3.000000    3.000000   20.0     2.400000
# 25%     239.250000    4.542500   20.0     3.634000
# 50%     503.500000    6.210000   20.0     4.968000
# 75%     750.750000    8.140000   20.0     6.512000
# max    1000.000000   10.000000   20.0     8.000000

# %%
df.price_total.describe()
# Out:
# count    654.000000
# mean       5.097431
# std        1.642802
# min        2.400000
# 25%        3.634000
# 50%        4.968000
# 75%        6.512000
# max        8.000000
# Name: price_total, dtype: float64

# %%
df.price_total.sum()
# Out:
# 3333.7200000000003

# %%
df.price_paid.sum()
# Out:
# 4167.15

# %%
df.price_paid.mean()
# Out:
# 6.371788990825688

# %%
df.price_paid.max()
# Out:
# 10.0

# %%
df.price_paid.min()
# Out:
# 3.0

# %%
df.country.unique()
# Out:
# array(['UN', 'MA', 'FR', 'CA', nan], dtype=object)

# %%
df.country.value_counts()
# Out:
# country
# FR    255
# UN    226
# CA    108
# MA     39
# Name: count, dtype: int64

# %%
df.groupby("country")["price_paid"].sum()
# Out:
# country
# CA     670.95
# FR    1611.71
# MA     263.81
# UN    1473.60
# Name: price_paid, dtype: float64

# %%
df.groupby("gender")["price_paid"].sum()
# Out:
# gender
# Female    2067.05
# Male      1814.74
# Name: price_paid, dtype: float64

# %%
df.groupby(["gender","country"])["price_paid"].sum()
# Out:
# gender  country
# Female  CA         321.43
#         FR         767.54
#         MA         156.96
#         UN         733.82
# Male    CA         296.92
#         FR         740.15
#         MA          88.30
#         UN         639.70
# Name: price_paid, dtype: float64

# %%
#graphique avec matplotlib

# %%
from matplotlib import plt
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[153], line 1
# ----> 1 from matplotlib import plt
#
# ImportError: cannot import name 'plt' from 'matplotlib' (C:\Users\harou\anaconda3\Lib\site-packages\matplotlib\__init__.py)

# %%
# !pip install matplotlib

# %%
df.groupby("date")["price_paid"].sum().plot(figsize=[20, 10])
# Out:
# <Axes: xlabel='date'>

# %%
#autre type de graphiques

# %%
df.groupby("gender")["price_paid"].sum().plot.pie(legend=True, figsize = [7,7])
# Out:
# <Axes: ylabel='price_paid'>

# %%
#la somme du prix payé par pays
df.groupby("country")["price_paid"].sum().plot.bar(legend=True, figsize=[7,7])
# Out:
# <Axes: xlabel='country'>
