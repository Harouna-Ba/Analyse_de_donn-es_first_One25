# %%
import pandas as pd

# %%
#import des données netflix
dfNet = pd.read_csv("netflix_titles.csv")

# %%
dfNet
# Out:
#      show_id     type                                    title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                     7:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7782   s7783    Movie                                     Zozo
# 7783   s7784    Movie                                   Zubaan
# 7784   s7785    Movie                        Zulu Man in Japan
# 7785   s7786  TV Show                    Zumbo's Just Desserts
# 7786   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                director                                               cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
dfNet.shape
# Out:
# (7787, 12)

# %%
dfNet.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
dfNet.country
# Out:
# 0                                                  Brazil
# 1                                                  Mexico
# 2                                               Singapore
# 3                                           United States
# 4                                           United States
#                               ...
# 7782    Sweden, Czech Republic, United Kingdom, Denmar...
# 7783                                                India
# 7784                                                  NaN
# 7785                                            Australia
# 7786                United Kingdom, Canada, United States
# Name: country, Length: 7787, dtype: object

# %%
dfNet[dfNet.country == "Brazil"]
# Out:
#      show_id     type                      title  \
# 0         s1  TV Show                         3%
# 208     s209    Movie           A new Capitalism
# 218     s219  TV Show            A Queen Is Born
# 320     s321    Movie  Afonso Padilha: Classless
# 322     s323  TV Show        Afronta! Facing It!
# ...      ...      ...                        ...
# 6655   s6656  TV Show              The Mechanism
# 7044   s7045    Movie      Thiago Ventura: POKAS
# 7383   s7384  TV Show                 Vai Anitta
# 7590   s7591    Movie   Whindersson Nunes: Adult
# 7756   s7757  TV Show                         Z4
#
#                            director  \
# 0                               NaN
# 208                             NaN
# 218                    Carla Barros
# 320    Junior Carelli, Rudge Campos
# 322                 Juliana Vicente
# ...                             ...
# 6655                            NaN
# 7044  Fabio Ock, Joana Mazzucchelli
# 7383                            NaN
# ...

# %%
dfNet.drop(["description","listed_in"], axis = 1, inplace = True)

# %%
dfNet
# Out:
#      show_id     type                                    title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                     7:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7782   s7783    Movie                                     Zozo
# 7783   s7784    Movie                                   Zubaan
# 7784   s7785    Movie                        Zulu Man in Japan
# 7785   s7786  TV Show                    Zumbo's Just Desserts
# 7786   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                director                                               cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
# !pip install matplotlib

# %%
dfNet.title.describe()
# Out:
# count     7787
# unique    7787
# top         3%
# freq         1
# Name: title, dtype: object

# %%
dfNet.groupby("type")["country"]
